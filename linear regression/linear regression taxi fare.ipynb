# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# %%
# Load the dataset
data = pd.read_csv('C:/Users/Sumanth/Downloads/taxi fare.csv')
data
# Out:
#       trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0               748               2.75                  1   75.00   24
# 1              1187               3.43                  1  105.00   24
# 2               730               3.12                  1   71.25    0
# 3               671               5.63                  3   90.00    0
# 4               329               2.09                  1   45.00   12
# ...             ...                ...                ...     ...  ...
# 1994            605               2.91                  1   67.50   19
# 1995            381               5.39                  1   78.75   18
# 1996            247               1.03                  1   33.75    0
# 1997           1826               6.39                  1  150.00    0
# 1998            533               3.85                  1   63.75   15
#
#       miscellaneous_fees  total_fare  surge_applied
# 0                  6.300     105.300              0
# 1                 13.200     142.200              0
# 2                 26.625      97.875              1
# 3                  9.750      99.750              0
# 4                 13.200      70.200              0
# ...                  ...         ...            ...
# 1994              26.450     112.950              1
# 1995               9.450     106.200              0
# 1996               6.000      39.750              0
# 1997              13.500     163.500              0
# 1998               6.000      84.750              0
#
# [1999 rows x 8 columns]

# %%
# Exclude non-numeric columns
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix = numeric_data.corr()

# Extract the correlation values with the target variable (e.g., 'price')
correlation_with_price = correlation_matrix['total_fare']

# Identify variables with positive correlation
positive_correlation = correlation_with_price[correlation_with_price > 0]

# Display the variables with positive correlation
print("Variables with Positive Correlation:")
print(positive_correlation)
# Out:
# Variables with Positive Correlation:
# trip_duration         0.116945
# distance_traveled     0.883044
# num_of_passengers     0.016986
# fare                  0.968419
# tip                   0.576903
# miscellaneous_fees    0.510668
# total_fare            1.000000
# surge_applied         0.251532
# Name: total_fare, dtype: float64

# %%
# Selecting only the 'distance_traveled' and 'fare' columns from the DataFrame
data=data[['distance_traveled','fare']]
data
# Out:
#       distance_traveled    fare
# 0                  2.75   75.00
# 1                  3.43  105.00
# 2                  3.12   71.25
# 3                  5.63   90.00
# 4                  2.09   45.00
# ...                 ...     ...
# 1994               2.91   67.50
# 1995               5.39   78.75
# 1996               1.03   33.75
# 1997               6.39  150.00
# 1998               3.85   63.75
#
# [1999 rows x 2 columns]

# %%
# Extracting the 'distance_traveled' column as the feature (X)
X=data[['distance_traveled']]
# Extracting the 'fare' column as the target variable (Y)
Y=data[['fare']]

# %%
X
# Out:
#       distance_traveled
# 0                  2.75
# 1                  3.43
# 2                  3.12
# 3                  5.63
# 4                  2.09
# ...                 ...
# 1994               2.91
# 1995               5.39
# 1996               1.03
# 1997               6.39
# 1998               3.85
#
# [1999 rows x 1 columns]

# %%
Y
# Out:
#         fare
# 0      75.00
# 1     105.00
# 2      71.25
# 3      90.00
# 4      45.00
# ...      ...
# 1994   67.50
# 1995   78.75
# 1996   33.75
# 1997  150.00
# 1998   63.75
#
# [1999 rows x 1 columns]

# %%
# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
len(X_train)
# Out:
# 1399

# %%
len(X_test)
# Out:
# 600

# %%
# Create a Linear Regression model
model = LinearRegression()
# Fit the model to the training data
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test data using the trained model
Y_pred_test = model.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# After making predictions (y_pred) and having the actual target values (y_test)
# Calculate R-squared
r2 = r2_score(Y_test, Y_pred_test)

# Calculate mean squared error (MSE)
mse = mean_squared_error(Y_test, Y_pred_test)

# Print the results
print("R-squared:", r2)
print("Mean squared error:", mse)
# Out:
# R-squared: 0.8156727907663325
# Mean squared error: 963.7566261491261
