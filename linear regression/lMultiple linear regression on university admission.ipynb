# %% [markdown]
# import pas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib .pyplot as plt

# %%
data = pd.read_csv('C:/Users/Sumanth/Downloads/archive (4)/adm_data.csv')
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
# Exclude non-numeric columns
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix = numeric_data.corr()

# Extract the correlation values with the target variable (e.g., 'price')
correlation_with_price = correlation_matrix['Chance of Admit ']

# Identify variables with positive correlation
positive_correlation = correlation_with_price[correlation_with_price > 0]

# Display the variables with positive correlation
print("Variables with Positive Correlation:")
print(positive_correlation)
# Out:
# Variables with Positive Correlation:
# GRE Score           0.802610
# TOEFL Score         0.791594
# CGPA                0.873289
# Chance of Admit     1.000000
# Name: Chance of Admit , dtype: float64

# %%
data=data[['GRE Score', 'TOEFL Score', 'CGPA','Chance of Admit ']]
data
# Out:
#      GRE Score  TOEFL Score  CGPA  Chance of Admit
# 0          337          118  9.65              0.92
# 1          324          107  8.87              0.76
# 2          316          104  8.00              0.72
# 3          322          110  8.67              0.80
# 4          314          103  8.21              0.65
# ..         ...          ...   ...               ...
# 395        324          110  9.04              0.82
# 396        325          107  9.11              0.84
# 397        330          116  9.45              0.91
# 398        312          103  8.78              0.67
# 399        333          117  9.66              0.95
#
# [400 rows x 4 columns]

# %%
X=data[['GRE Score','TOEFL Score', 'CGPA']]
Y=data[ 'Chance of Admit ']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=42)

# %%
len(X_train)
# Out:
# 240

# %%
len(Y_train)
# Out:
# 240

# %%
len(X_test)
# Out:
# 160

# %%
len(Y_test)
# Out:
# 160

# %%
model = LinearRegression()

# Train the model
Y_pred_train=model.fit(X_train, Y_train)
Y_pred_train
# Out:
# LinearRegression()

# %%
Y_pred_test=model.predict(X_test)
Y_pred_test
# Out:
# array([0.61132851, 0.7074237 , 0.94952322, 0.81871001, 0.56227138,
#        0.93086475, 0.5501762 , 0.54172403, 0.69047386, 0.86045923,
#        0.74901541, 0.92875012, 0.54878978, 0.86847172, 0.69735302,
#        0.70471736, 0.68032399, 0.48610909, 0.69568988, 0.97279421,
#        0.61409128, 0.6752099 , 0.73744456, 0.5516254 , 0.9569777 ,
#        0.82344085, 0.68766011, 0.57356006, 0.66221807, 0.82906288,
#        0.81757668, 0.93745079, 0.63810141, 0.51929873, 0.66987006,
#        0.67087324, 0.73946907, 0.65220382, 0.6326487 , 0.90251884,
#        0.74081086, 0.60406063, 0.78591544, 0.96292106, 0.83139144,
#        0.83289708, 0.97903069, 0.6710653 , 0.9062966 , 0.84792436,
#        0.87678914, 0.71779931, 0.7685141 , 0.94151621, 0.58749403,
#        0.57864681, 0.68815077, 0.82448406, 0.59009843, 0.81638692,
#        0.66454117, 0.67469102, 0.67642789, 0.49638277, 0.64451267,
#        0.70732263, 0.59966753, 0.84664447, 0.86034088, 0.78497329,
# ...

# %%
from sklearn.metrics import r2_score, mean_squared_error

# After making predictions (y_pred) and having the actual target values (y_test)
# Calculate R-squared
r2 = r2_score(Y_test, Y_pred_test)

# Calculate mean squared error (MSE)
mse = mean_squared_error(Y_test, Y_pred_test)

# Print the results
print("R-squared:", r2)
print("Mean squared error:", mse)
# Out:
# R-squared: 0.7598203959901082
# Mean squared error: 0.005119457343719766
